# %%
import os
print('INPUTS:', os.listdir('/kaggle/input'))
for d in os.listdir('/kaggle/input'):
    p = os.path.join('/kaggle/input', d)
    print(d, '->', os.listdir(p)[:8] if os.path.isdir(p) else 'file')
print('HELLO-TEST OK')
